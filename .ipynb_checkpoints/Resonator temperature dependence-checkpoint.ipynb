# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation
import os
import h5py as h5
import sys
import cmath
import lmfit
if os.path.exists('D:/PycQED'):
    sys.path.append('D:/PycQED/modules')
    sys.path.append('D:/PycQED/qtlab/source')
elif os.path.exists('C:/PycQED'):
    sys.path.append('C:/PycQED/modules')
    sys.path.append('C:/PycQED/qtlab/source')
else:
    raise NameError('Cannot find PycQED directory')
# from utils import *
import analysis.fitting_models as fm
SlopedHangerModel = fm.SlopedHangerModel
# %pylab
# Out:
# Using matplotlib backend: GTKAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
path = r'D:\qtlab\data\VNA_T_dependence\data'
if not os.path.exists(path):
    path = r'C:\PycQED\data\VNA_T_dependence\data'
    if not os.path.exists(path):
        raise NameError('Cannot find data')

# %%
filenames = os.listdir(path)
for k, filename in enumerate(filenames):
    if filename[:6] == '141527': #Point where power was changed to -60
        break
filenames = filenames[k:]

filepath = os.path.join(path,filenames[k])
data=h5.File(filepath,'r')
freq = data['Experimental_Data']['Frequency'].value
fmin = freq[0]
fmax = freq[-1]

# %% [markdown]
# ## Fitting

# %%
def fit_complex_data(data, x, pars):
    def residuals_complex(pars, fit_func, data):
        res = fit_func(pars) - data
        return np.array([res.real, res.imag])
    lmfit.minimize(residuals_complex, pars, args=(fit_func,data),xtol=tol,ftol=tol)

# %%
def fit_estimate_parameters(x, y):
    #Temps to make param estimations
    ya = np.abs(y[:])
    phi_0 = cmath.phase(y[0])
    phi_v = 0
    s21min = np.abs(min(ya)/max(ya))

    y_rotated = y*np.exp(-1.j*(phi_v*x+phi_0-phi_v*x[0]))
    y_min = np.argmin(y_rotated.imag)
    y_max = np.argmax(y_rotated.imag)

    #Parameters
    A = (ya[0]+ya[-1])/2.
    f0 = x[ya[:].tolist().index(min(ya[:]))]
    Q = f0/(abs(x[y_min]-x[y_max]))
    Qe = np.abs(Q/np.abs(1-s21min))
    phi_0 = phi_0


    params = SlopedHangerModel.make_params()
    params['A'].value = A
    params['f0'].value = f0
    params['Q'].value = Q
    params['Qe'].value = Qe
    params['df'].value = 0.
    params['theta'].value = 0.
    params['phi_v'].value = phi_v
    params['phi_0'].value = phi_0
    params.add('Qi', expr = '1./(1./Q-1./Qe*cos(theta))', vary=False)
    params.add('Qc', expr = 'Qe/cos(theta)', vary=False)
    return params

# %%
def fit_hanger(freq_lst, S21_lst):
    params = fit_estimate_parameters(freq_lst, S21_lst)
    fit = SlopedHangerModel.fit(data = S21_lst, f = freq_lst, params = params)
    return fit

# %%
filepath = os.path.join(path,filenames[0])
if os.path.exists(filepath):
    data=h5.File(filepath,'r')
else:
    raise NameError('Data file not found!')
freq = data['Experimental_Data']['Frequency'].value
S21 = data['Experimental_Data']['S21 (comp)'].value

# %%
fit_hanger(freq, S21)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: Cannot cast array data from dtype('complex128') to dtype('float64') according to the rule 'safe'
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-8-c9aa8da8d493> in <module>()
# ----> 1 fit_hanger(freq, S21)
#
# <ipython-input-6-a8ab8525b717> in fit_hanger(freq_lst, S21_lst)
#       1 def fit_hanger(freq_lst, S21_lst):
#       2     params = fit_estimate_parameters(freq_lst, S21_lst)
# ----> 3     fit = SlopedHangerModel.fit(data = S21_lst, f = freq_lst, params = params)
#       4     return fit
#
# C:\Python27\lib\site-packages\lmfit\model.pyc in fit(self, data, params, weights, method, iter_cb, scale_covar, verbose, fit_kws, **kwargs)
#     504         output = ModelFit(self, params, method=method, iter_cb=iter_cb,
#     505                           scale_covar=scale_covar, fcn_kws=kwargs, **fit_kws)
# --> 506         output.fit(data=data, weights=weights)
#     507         return output
#     508
#
# C:\Python27\lib\site-packages\lmfit\model.pyc in fit(self, data, params, weights, method, **kwargs)
#     591         self.init_fit    = self.model.eval(params=self.init_params, **self.userkws)
#     592
# --> 593         self.minimize(method=self.method)
#     594         self.best_fit = self.model.eval(params=self.params, **self.userkws)
#     595         self.best_values = self.model._make_all_args(self.params)
#
# C:\Python27\lib\site-packages\lmfit\minimizer.pyc in minimize(self, method)
#     579             function = self.lbfgsb
#     580
# --> 581         return function(**kwargs)
#     582
#     583
#
# C:\Python27\lib\site-packages\lmfit\minimizer.pyc in leastsq(self, **kws)
#     454         orig_warn_settings = np.geterr()
#     455         np.seterr(all='ignore')
# --> 456         lsout = scipy_leastsq(self.__residual, self.vars, **lskws)
#     457         _best, _cov, infodict, errmsg, ier = lsout
#     458
#
# C:\Python27\lib\site-packages\scipy\optimize\minpack.pyc in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     377             maxfev = 200*(n + 1)
#     378         retval = _minpack._lmdif(func, x0, args, full_output, ftol, xtol,
# --> 379                                  gtol, maxfev, epsfcn, factor, diag)
#     380     else:
#     381         if col_deriv:
#
# error: Result from function call is not a proper array of floats.

# %% [markdown]
# ## Test fitting

# %%
def line(f,a,b):
    return a + b * f + 1.j

# %%
lineModel = lmfit.Model(line)
params = lineModel.make_params()
params['a'].value = 0
params['b'].value = 2

# %%
f = np.arange(100)
y = np.random.randn(100)

# %%
fit = lineModel.fit(data=y,params = params, f = f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: Cannot cast array data from dtype('complex128') to dtype('float64') according to the rule 'safe'
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-24-df5a51f30fa0> in <module>()
# ----> 1 fit = lineModel.fit(data=y,params = params, f = f)
#
# C:\Python27\lib\site-packages\lmfit\model.pyc in fit(self, data, params, weights, method, iter_cb, scale_covar, verbose, fit_kws, **kwargs)
#     504         output = ModelFit(self, params, method=method, iter_cb=iter_cb,
#     505                           scale_covar=scale_covar, fcn_kws=kwargs, **fit_kws)
# --> 506         output.fit(data=data, weights=weights)
#     507         return output
#     508
#
# C:\Python27\lib\site-packages\lmfit\model.pyc in fit(self, data, params, weights, method, **kwargs)
#     591         self.init_fit    = self.model.eval(params=self.init_params, **self.userkws)
#     592
# --> 593         self.minimize(method=self.method)
#     594         self.best_fit = self.model.eval(params=self.params, **self.userkws)
#     595         self.best_values = self.model._make_all_args(self.params)
#
# C:\Python27\lib\site-packages\lmfit\minimizer.pyc in minimize(self, method)
#     579             function = self.lbfgsb
#     580
# --> 581         return function(**kwargs)
#     582
#     583
#
# C:\Python27\lib\site-packages\lmfit\minimizer.pyc in leastsq(self, **kws)
#     454         orig_warn_settings = np.geterr()
#     455         np.seterr(all='ignore')
# --> 456         lsout = scipy_leastsq(self.__residual, self.vars, **lskws)
#     457         _best, _cov, infodict, errmsg, ier = lsout
#     458
#
# C:\Python27\lib\site-packages\scipy\optimize\minpack.pyc in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     377             maxfev = 200*(n + 1)
#     378         retval = _minpack._lmdif(func, x0, args, full_output, ftol, xtol,
# --> 379                                  gtol, maxfev, epsfcn, factor, diag)
#     380     else:
#     381         if col_deriv:
#
# error: Result from function call is not a proper array of floats.

# %%
plt.figure('test fit')
plt.clf()
plt.plot(f, y)
plt.plot(f,fit.best_fit)

# %% [markdown]
# ## Animation

# %%
def init():
    resonatorline.set_data([], [])
    resonatorfitline.set_data([], [])
#     Qiline.set_data([], [])
#     f0line.set_data([], [])
    return (resonatorline, resonatorfitline)#, Qiline, f0line)

# %%
# animation function.  This is called sequentially
def show_plot(i):
    filepath = os.path.join(path,filenames[i])
    if os.path.exists(filepath):
        data=h5.File(filepath,'r')
    else:
        raise NameError('Data file not found!')
    freq = data['Experimental_Data']['Frequency'].value
    S21 = data['Experimental_Data']['S21 (comp)'].value
    
    fres = fit_S21_resonance_complex(freq,S21)
    Qi = fres['fitparsobj']['Qi'].value
    f0 = fres['fitparsobj']['f0'].value
    if 'temperature' in data['Experimental_Data'].keys():
        temperature = data['Experimental_Data']['temperature'].value
        show_plot.temperature += [temperature]
        show_plot.Qi += [Qi]
        show_plot.f0 += [f0]
    
    resonatorline.set_data(freq, np.abs(S21))
    resonatorfitline.set_data(freq, np.abs(fres['fit']))
    
#     if len(show_plot.temperature) != 0:
# #         npoints = len(show_plot.temperature)
#         Qiline.set_data(show_plot.temperature, show_plot.Qi)
#         f0line.set_data(show_plot.temperature, show_plot.f0)
#     else:
#         Qiline.set_data([], [])
#         f0line.set_data([], [])
        
    
    
    plt.subplot(311)
    plt.title('%d of %d' % (i + 1, len(filenames)))
    plt.draw()
    
    print '*'*15
    print show_plot.Qi
    print show_plot.f0
    print show_plot.temperature
#     plt.subplot(312)
    
    return (resonatorline, resonatorfitline, Qiline, f0line)
show_plot.Qi = []
show_plot.f0 = []
show_plot.temperature = []

# %%
class ResonatorAnimation(animation.TimedAnimation):
    def __init__(self):
        fig = plt.figure('Resonator during cooldown')

        ax1 = fig.add_subplot(3,1,1)
        ax2 = fig.add_subplot(3,1,2)
        ax3 = fig.add_subplot(3,1,3)

        ax1.set_xlabel('Frequency (GHz)')
        ax1.set_ylabel('S21 (mV)')
        self.lineresonator = Line2D([], [])
        self.lineresonatorfit = Line2D([], [])
        ax1.add_line(self.lineresonator)
        ax1.add_line(self.lineresonatorfit)
        ax1.set_ylim(0,0.045)



        ax2.set_xlabel('Temperature (mK)')
        ax2.set_ylabel('Internal quality factor')
        self.lineQi = Line2D([], [])
        ax2.add_line(self.lineQi)



        ax3.set_xlabel('Temperature (mK)')
        ax3.set_ylabel('Center frequency')
        self.linef0 = Line2D([], [])
        ax3.add_line(self.linef0)

        for ax in [ax1,ax2,ax3]:
            ax.get_xaxis().get_major_formatter().set_useOffset(False)
            ax.get_yaxis().get_major_formatter().set_useOffset(False)

        self._temperature = []
        self._Qi = []
        self._f0 = []

        animation.TimedAnimation.__init__(self, fig, interval=50, blit=True)

    def _draw_frame(self, framedata):
        i = framedata

        filepath = os.path.join(path,filenames[i])
        if os.path.exists(filepath):
            data=h5.File(filepath,'r')
        else:
            raise NameError('Data file not found!')
        freq = data['Experimental_Data']['Frequency'].value
        S21 = data['Experimental_Data']['S21 (comp)'].value
        
        fres = fit_S21_resonance_complex(freq,S21)
        Qi = fres['fitparsobj']['Qi'].value
        f0 = fres['fitparsobj']['f0'].value
        if 'temperature' in data['Experimental_Data'].keys():
            temperature = data['Experimental_Data']['temperature'].value
            self._temperature += [temperature]
            self._Qi += [Qi]
            self._f0 += [f0]
        
        self.lineresonator.set_data(freq, np.abs(S21))
        self.lineresonatorfit.set_data(freq, np.abs(fres['fit']))
        
        if len(self._temperature) != 0:
    #         npoints = len(self._temperature)
            self.lineQi.set_data(self._temperature, self._Qi)
            self.linef0.set_data(self._temperature, self._f0)
        else:
            self.lineQi.set_data([], [])
            self.linef0.set_data([], [])



        self._drawn_artists = [self.lineresonator, self.lineresonatorfit,
                               self.lineQi, self.linef0]

    def new_frame_seq(self):
        return iter(range(len(filenames)))

    def _init_draw(self):
        lines =  [self.lineresonator, self.lineresonatorfit,
                               self.lineQi, self.linef0]
        for l in lines:
            l.set_data([], [])


#         anim = animation.FuncAnimation(fig, show_plot, init_func=init,
#                                        frames=len(filenames), interval=100, blit=True,repeat=False)
#         plt.show()

# %%
ani = ResonatorAnimation()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\python27\lib\site-packages\matplotlib\backends\backend_gtk.pyc in _on_timer(self)
#     137
#     138     def _on_timer(self):
# --> 139         TimerBase._on_timer(self)
#     140
#     141         # Gtk timeout_add() requires that the callback returns True if it
#
# c:\python27\lib\site-packages\matplotlib\backend_bases.pyc in _on_timer(self)
#    1269         '''
#    1270         for func, args, kwargs in self.callbacks:
# -> 1271             ret = func(*args, **kwargs)
#    1272             # docstring above explains why we use `if ret == False` here,
#    1273             # instead of `if not ret`.
#
# c:\python27\lib\site-packages\matplotlib\animation.pyc in _step(self, *args)
#     908         # delay and set the callback to one which will then set the interval
#     909         # back.
# --> 910         still_going = Animation._step(self, *args)
#     911         if not still_going and self.repeat:
#     912             self.frame_seq = self.new_frame_seq()
#
# c:\python27\lib\site-packages\matplotlib\animation.pyc in _step(self, *args)
#     767         try:
#     768             framedata = next(self.frame_seq)
# --> 769             self._draw_next_frame(framedata, self._blit)
#     770             return True
#     771         except StopIteration:
#
# c:\python27\lib\site-packages\matplotlib\animation.pyc in _draw_next_frame(self, framedata, blit)
#     786         # post- draw, as well as the drawing of the frame itself.
#     787         self._pre_draw(framedata, blit)
# --> 788         self._draw_frame(framedata)
#     789         self._post_draw(framedata, blit)
#     790
#
# <ipython-input-14-78288682f3a4> in _draw_frame(self, framedata)
#      50         S21 = data['Experimental_Data']['S21 (comp)'].value
#      51
# ---> 52         fres = fit_S21_resonance_complex(freq,S21)
#      53         Qi = fres['fitparsobj']['Qi'].value
#      54         f0 = fres['fitparsobj']['f0'].value
#
# D:\qtlab\modules\utils\__init__.py in fit_S21_resonance_complex(*args, **kw)
#      62         print 'init guess: ',p0i
#      63     pars = S21p0i2paramsc(x,p0i)
# ---> 64     fr = fit.fitxy(pars,y, fn.disp_hanger_S21_complex_sloped, ret_fit=True)
#      65     if not silent:
#      66         fit.print_fitres(pars)
#
# D:\qtlab\modules\fit_toolbox\fit.pyc in fitxy(pars, data, fit_func, **kw)
#      25     tol = kw.pop('xtol',1.e-10)
#      26     #print 'tol: ',tol
# ---> 27     result = minimize(residuals_lmfit, pars, args=(fit_func,data),xtol=tol,ftol=tol)
#      28     #print result
#      29     #rep = report_fit(result)
#
# c:\python27\lib\site-packages\lmfit-0.8.2-py2.7.egg\lmfit\minimizer.pyc in minimize(fcn, params, method, args, kws, scale_covar, iter_cb, **fit_kws)
#     814     fitter = Minimizer(fcn, params, fcn_args=args, fcn_kws=kws,
#     815                        iter_cb=iter_cb, scale_covar=scale_covar, **fit_kws)
# --> 816     fitter.minimize(method=method)
#     817     return fitter
#
# c:\python27\lib\site-packages\lmfit-0.8.2-py2.7.egg\lmfit\minimizer.pyc in minimize(self, method)
#     745             function = self.lbfgsb
#     746
# --> 747         return function(**kwargs)
#     748
#     749
#
# c:\python27\lib\site-packages\lmfit-0.8.2-py2.7.egg\lmfit\minimizer.pyc in leastsq(self, **kws)
#     696
#     697         np.seterr(**orig_warn_settings)
# --> 698         self.unprepare_fit()
#     699         return self.success
#     700
#
# c:\python27\lib\site-packages\lmfit-0.8.2-py2.7.egg\lmfit\minimizer.pyc in unprepare_fit(self)
#     393         """
#     394         self.__prepared = False
# --> 395         self.params = deepcopy(self.params)
#     396         for par in self.params.values():
#     397             if hasattr(par, 'ast'):
#
# c:\python27\lib\copy.pyc in deepcopy(x, memo, _nil)
#     188                             raise Error(
#     189                                 "un(deep)copyable object of type %s" % cls)
# --> 190                 y = _reconstruct(x, rv, 1, memo)
#     191
#     192     memo[d] = y
#
# c:\python27\lib\copy.pyc in _reconstruct(x, info, deep, memo)
#     326         dictiter = None
#     327     if deep:
# --> 328         args = deepcopy(args, memo)
#     329     y = callable(*args)
#     330     memo[id(x)] = y
#
# c:\python27\lib\copy.pyc in deepcopy(x, memo, _nil)
#     161     copier = _deepcopy_dispatch.get(cls)
#     162     if copier:
# --> 163         y = copier(x, memo)
#     164     else:
#     165         try:
#
# c:\python27\lib\copy.pyc in _deepcopy_tuple(x, memo)
#     235     y = []
#     236     for a in x:
# --> 237         y.append(deepcopy(a, memo))
#     238     d = id(x)
#     239     try:
#
# c:\python27\lib\copy.pyc in deepcopy(x, memo, _nil)
#     161     copier = _deepcopy_dispatch.get(cls)
#     162     if copier:
# --> 163         y = copier(x, memo)
#     164     else:
#     165         try:
#
# c:\python27\lib\copy.pyc in _deepcopy_list(x, memo)
#     228     memo[id(x)] = y
#     229     for a in x:
# --> 230         y.append(deepcopy(a, memo))
#     231     return y
#     232 d[list] = _deepcopy_list
#
# c:\python27\lib\copy.pyc in deepcopy(x, memo, _nil)
#     161     copier = _deepcopy_dispatch.get(cls)
#     162     if copier:
# --> 163         y = copier(x, memo)
#     164     else:
#     165         try:
#
# c:\python27\lib\copy.pyc in _deepcopy_list(x, memo)
#     228     memo[id(x)] = y
#     229     for a in x:
# --> 230         y.append(deepcopy(a, memo))
#     231     return y
#     232 d[list] = _deepcopy_list
#
# c:\python27\lib\copy.pyc in deepcopy(x, memo, _nil)
#     188                             raise Error(
#     189                                 "un(deep)copyable object of type %s" % cls)
# --> 190                 y = _reconstruct(x, rv, 1, memo)
#     191
#     192     memo[d] = y
#
# c:\python27\lib\copy.pyc in _reconstruct(x, info, deep, memo)
#     334             state = deepcopy(state, memo)
#     335         if hasattr(y, '__setstate__'):
# --> 336             y.__setstate__(state)
#     337         else:
#     338             if isinstance(state, tuple) and len(state) == 2:
#
# c:\python27\lib\site-packages\lmfit-0.8.2-py2.7.egg\lmfit\parameter.pyc in __setstate__(self, state)
#     204          self.max, self.stderr, self.correl, self.init_value) = state
#     205         self._val = self.value
# --> 206         self._init_bounds()
#     207
#     208     def __repr__(self):
#
# c:\python27\lib\site-packages\lmfit-0.8.2-py2.7.egg\lmfit\parameter.pyc in _init_bounds(self)
#     184         #_val is None means - infinity.
#     185         if self._val is not None:
# --> 186             if self.max is not None and self._val > self.max:
#     187                 self._val = self.max
#     188             if self.min is not None and self._val < self.min:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\python27\lib\site-packages\matplotlib\backends\backend_gtk.pyc in _on_timer(self)
#     137
#     138     def _on_timer(self):
# --> 139         TimerBase._on_timer(self)
#     140
#     141         # Gtk timeout_add() requires that the callback returns True if it
#
# c:\python27\lib\site-packages\matplotlib\backend_bases.pyc in _on_timer(self)
#    1269         '''
#    1270         for func, args, kwargs in self.callbacks:
# -> 1271             ret = func(*args, **kwargs)
#    1272             # docstring above explains why we use `if ret == False` here,
#    1273             # instead of `if not ret`.
#
# c:\python27\lib\site-packages\matplotlib\animation.pyc in _step(self, *args)
#     908         # delay and set the callback to one which will then set the interval
#     909         # back.
# --> 910         still_going = Animation._step(self, *args)
#     911         if not still_going and self.repeat:
#     912             self.frame_seq = self.new_frame_seq()
#
# c:\python27\lib\site-packages\matplotlib\animation.pyc in _step(self, *args)
#     767         try:
#     768             framedata = next(self.frame_seq)
# --> 769             self._draw_next_frame(framedata, self._blit)
#     770             return True
#     771         except StopIteration:
#
# c:\python27\lib\site-packages\matplotlib\animation.pyc in _draw_next_frame(self, framedata, blit)
#     786         # post- draw, as well as the drawing of the frame itself.
#     787         self._pre_draw(framedata, blit)
# --> 788         self._draw_frame(framedata)
#     789         self._post_draw(framedata, blit)
#     790
#
# <ipython-input-14-78288682f3a4> in _draw_frame(self, framedata)
#      50         S21 = data['Experimental_Data']['S21 (comp)'].value
#      51
# ---> 52         fres = fit_S21_resonance_complex(freq,S21)
#      53         Qi = fres['fitparsobj']['Qi'].value
#      54         f0 = fres['fitparsobj']['f0'].value
#
# D:\qtlab\modules\utils\__init__.py in fit_S21_resonance_complex(*args, **kw)
#      62         print 'init guess: ',p0i
#      63     pars = S21p0i2paramsc(x,p0i)
# ---> 64     fr = fit.fitxy(pars,y, fn.disp_hanger_S21_complex_sloped, ret_fit=True)
#      65     if not silent:
#      66         fit.print_fitres(pars)
#
# D:\qtlab\modules\fit_toolbox\fit.pyc in fitxy(pars, data, fit_func, **kw)
#      25     tol = kw.pop('xtol',1.e-10)
#      26     #print 'tol: ',tol
# ---> 27     result = minimize(residuals_lmfit, pars, args=(fit_func,data),xtol=tol,ftol=tol)
#      28     #print result
#      29     #rep = report_fit(result)
#
# c:\python27\lib\site-packages\lmfit-0.8.2-py2.7.egg\lmfit\minimizer.pyc in minimize(fcn, params, method, args, kws, scale_covar, iter_cb, **fit_kws)
#     814     fitter = Minimizer(fcn, params, fcn_args=args, fcn_kws=kws,
#     815                        iter_cb=iter_cb, scale_covar=scale_covar, **fit_kws)
# --> 816     fitter.minimize(method=method)
#     817     return fitter
#
# c:\python27\lib\site-packages\lmfit-0.8.2-py2.7.egg\lmfit\minimizer.pyc in minimize(self, method)
#     745             function = self.lbfgsb
#     746
# --> 747         return function(**kwargs)
#     748
#     749
#
# c:\python27\lib\site-packages\lmfit-0.8.2-py2.7.egg\lmfit\minimizer.pyc in leastsq(self, **kws)
#     696
#     697         np.seterr(**orig_warn_settings)
# --> 698         self.unprepare_fit()
#     699         return self.success
#     700
#
# c:\python27\lib\site-packages\lmfit-0.8.2-py2.7.egg\lmfit\minimizer.pyc in unprepare_fit(self)
#     393         """
#     394         self.__prepared = False
# --> 395         self.params = deepcopy(self.params)
#     396         for par in self.params.values():
#     397             if hasattr(par, 'ast'):
#
# c:\python27\lib\copy.pyc in deepcopy(x, memo, _nil)
#     188                             raise Error(
#     189                                 "un(deep)copyable object of type %s" % cls)
# --> 190                 y = _reconstruct(x, rv, 1, memo)
#     191
#     192     memo[d] = y
#
# c:\python27\lib\copy.pyc in _reconstruct(x, info, deep, memo)
#     326         dictiter = None
#     327     if deep:
# --> 328         args = deepcopy(args, memo)
#     329     y = callable(*args)
#     330     memo[id(x)] = y
#
# c:\python27\lib\copy.pyc in deepcopy(x, memo, _nil)
#     161     copier = _deepcopy_dispatch.get(cls)
#     162     if copier:
# --> 163         y = copier(x, memo)
#     164     else:
#     165         try:
#
# c:\python27\lib\copy.pyc in _deepcopy_tuple(x, memo)
#     235     y = []
#     236     for a in x:
# --> 237         y.append(deepcopy(a, memo))
#     238     d = id(x)
#     239     try:
#
# c:\python27\lib\copy.pyc in deepcopy(x, memo, _nil)
#     161     copier = _deepcopy_dispatch.get(cls)
#     162     if copier:
# --> 163         y = copier(x, memo)
#     164     else:
#     165         try:
#
# c:\python27\lib\copy.pyc in _deepcopy_list(x, memo)
#     228     memo[id(x)] = y
#     229     for a in x:
# --> 230         y.append(deepcopy(a, memo))
#     231     return y
#     232 d[list] = _deepcopy_list
#
# c:\python27\lib\copy.pyc in deepcopy(x, memo, _nil)
#     161     copier = _deepcopy_dispatch.get(cls)
#     162     if copier:
# --> 163         y = copier(x, memo)
#     164     else:
#     165         try:
#
# c:\python27\lib\copy.pyc in _deepcopy_list(x, memo)
#     228     memo[id(x)] = y
#     229     for a in x:
# --> 230         y.append(deepcopy(a, memo))
#     231     return y
#     232 d[list] = _deepcopy_list
#
# c:\python27\lib\copy.pyc in deepcopy(x, memo, _nil)
#     188                             raise Error(
#     189                                 "un(deep)copyable object of type %s" % cls)
# --> 190                 y = _reconstruct(x, rv, 1, memo)
#     191
#     192     memo[d] = y
#
# c:\python27\lib\copy.pyc in _reconstruct(x, info, deep, memo)
#     334             state = deepcopy(state, memo)
#     335         if hasattr(y, '__setstate__'):
# --> 336             y.__setstate__(state)
#     337         else:
#     338             if isinstance(state, tuple) and len(state) == 2:
#
# c:\python27\lib\site-packages\lmfit-0.8.2-py2.7.egg\lmfit\parameter.pyc in __setstate__(self, state)
#     204          self.max, self.stderr, self.correl, self.init_value) = state
#     205         self._val = self.value
# --> 206         self._init_bounds()
#     207
#     208     def __repr__(self):
#
# c:\python27\lib\site-packages\lmfit-0.8.2-py2.7.egg\lmfit\parameter.pyc in _init_bounds(self)
#     184         #_val is None means - infinity.
#     185         if self._val is not None:
# --> 186             if self.max is not None and self._val > self.max:
#     187                 self._val = self.max
#     188             if self.min is not None and self._val < self.min:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %% [markdown]
# ## Animation example

# %%
# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

# animation function.  This is called sequentially
def animate(i):
    x = np.linspace(0, 2, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return line,

# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=200, interval=200, blit=True,repeat=False)

# save the animation as an mp4.  This requires ffmpeg or mencoder to be
# installed.  The extra_args ensure that the x264 codec is used, so that
# the video can be embedded in html5.  You may need to adjust this for
# your system: for more information, see
# http://matplotlib.sourceforge.net/api/animation_api.html
anim.save('basic_animation.mp4', fps=30, extra_args=['-vcodec', 'libx264'])

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import matplotlib.animation as animation

# This example uses subclassing, but there is no reason that the proper function
# couldn't be set up and then use FuncAnimation. The code is long, but not
# really complex. The length is due solely to the fact that there are a total
# of 9 lines that need to be changed for the animation as well as 3 subplots
# that need initial set up.
class SubplotAnimation(animation.TimedAnimation):
    def __init__(self):
        fig = plt.figure()
        ax1 = fig.add_subplot(1, 2, 1)
        ax2 = fig.add_subplot(2, 2, 2)
        ax3 = fig.add_subplot(2, 2, 4)

        self.t = np.linspace(0, 80, 400)
        self.x = np.cos(2 * np.pi * self.t / 10.)
        self.y = np.sin(2 * np.pi * self.t / 10.)
        self.z = 10 * self.t

        ax1.set_xlabel('x')
        ax1.set_ylabel('y')
        self.line1 = Line2D([], [], color='black')
        self.line1a = Line2D([], [], color='red', linewidth=2)
        self.line1e = Line2D([], [], color='red', marker='o', markeredgecolor='r')
        ax1.add_line(self.line1)
        ax1.add_line(self.line1a)
        ax1.add_line(self.line1e)
        ax1.set_xlim(-1, 1)
        ax1.set_ylim(-2, 2)
        ax1.set_aspect('equal', 'datalim')

        ax2.set_xlabel('y')
        ax2.set_ylabel('z')
        self.line2 = Line2D([], [], color='black')
        self.line2a = Line2D([], [], color='red', linewidth=2)
        self.line2e = Line2D([], [], color='red', marker='o', markeredgecolor='r')
        ax2.add_line(self.line2)
        ax2.add_line(self.line2a)
        ax2.add_line(self.line2e)
        ax2.set_xlim(-1, 1)
        ax2.set_ylim(0, 800)

        ax3.set_xlabel('x')
        ax3.set_ylabel('z')
        self.line3 = Line2D([], [], color='black')
        self.line3a = Line2D([], [], color='red', linewidth=2)
        self.line3e = Line2D([], [], color='red', marker='o', markeredgecolor='r')
        ax3.add_line(self.line3)
        ax3.add_line(self.line3a)
        ax3.add_line(self.line3e)
        ax3.set_xlim(-1, 1)
        ax3.set_ylim(0, 800)

        animation.TimedAnimation.__init__(self, fig, interval=50, blit=True)

    def _draw_frame(self, framedata):
        i = framedata
        head = i - 1
        head_len = 10
        head_slice = (self.t > self.t[i] - 1.0) & (self.t < self.t[i])

        self.line1.set_data(self.x[:i], self.y[:i])
        self.line1a.set_data(self.x[head_slice], self.y[head_slice])
        self.line1e.set_data(self.x[head], self.y[head])

        self.line2.set_data(self.y[:i], self.z[:i])
        self.line2a.set_data(self.y[head_slice], self.z[head_slice])
        self.line2e.set_data(self.y[head], self.z[head])

        self.line3.set_data(self.x[:i], self.z[:i])
        self.line3a.set_data(self.x[head_slice], self.z[head_slice])
        self.line3e.set_data(self.x[head], self.z[head])

        self._drawn_artists = [self.line1, self.line1a, self.line1e,
            self.line2, self.line2a, self.line2e,
            self.line3, self.line3a, self.line3e]

    def new_frame_seq(self):
        return iter(range(self.t.size))

    def _init_draw(self):
        lines =  [self.line1, self.line1a, self.line1e,
            self.line2, self.line2a, self.line2e,
            self.line3, self.line3a, self.line3e]
        for l in lines:
            l.set_data([], [])

ani = SubplotAnimation()
#ani.save('test_sub.mp4')
plt.show()
